# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.signal as signal
from scipy.fft import fft, ifft,fftshift
import control
import sympy as sp

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # a)

# %% [markdown]
# \begin{align*}
# y[n]&=3(x[n]+2x[n]+1/3y[n-1])+6x[n-1]\\
#     &=9x[n]+y[n-1]+6x[n-1]\\
#     &=9x[n]+6x[n-1]+y[n-1]\\
# \end{align*}

# %% [markdown]
# # b)

# %% [markdown]
# \begin{align*}
# Y(z)&=9X(z)+6z^{-1}X(z)+z^{-1}Y(z)\\
# H(z)&=\frac{9+6z^{-1}}{1-z^{-1}}\\
# \end{align*}

# %% [markdown]
# \begin{align*}
# A(1-z^{-1})+B=9+6^z{-1}\\\\
# -A&=6\\
# A&=-6\\\\
# A+B&=9\\
# B&=9-A\\
# B&=9+6\\
# B&=15
# \end{align*}

# %% [markdown]
# $$H(z)=\frac{15}{1-z^{-1}}-6$$
# $$h[n]=15u[n]-6\delta [n]$$

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# kun d)

# %% [markdown]
# # d)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# kun c)

# %% [markdown]
# # c)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

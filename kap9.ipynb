# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.signal as signal
from scipy.fft import fft, ifft,fftshift
import control
import sympy as sp

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # a)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# \begin{align*}
# v[n]&=x[n]+1/3v[n-1]\\
# y[n]&=3(v[n]+2x[n])+6v[n-1]\\
#     &=6x[n]+3v[n]+6v[n-1]\\
# \end{align*}

# %% [markdown]
# \begin{align*}
# V(z)&=X(z)+1/3z^{-1}V(z)\\\\
# \frac{V(z)}{X(z)}&=\frac{1}{1-1/3z^{-1}}\\
# \end{align*}

# %% [markdown]
# \begin{align*}
# X(z)&=V(z)-1/3z^{-1}V(z)\\\\
# Y(z)&=6X(z)+3V(z)+6z^{-1}V(z)\\
# Y(z)&=6(V(z)-1/3z^{-1}V(z))+3V(z)+6z^{-1}V(z)\\
# Y(z)&=9V(z)+4z^{-1}V(z)\\
# \frac{Y(z)}{V(z)}&=9+4z^{-1}
# \end{align*}

# %% [markdown]
# \begin{align*}
# \frac{Y(z)}{X(z)}&=\frac{Y(z)}{V(z)}\frac{V(z)}{X(z)}=\frac{9+4z^{-1}}{1-1/3z^{-1}}\\
# Y(z)(1-1/3z^{-1})&=(9+4z^{-1})X(z)\\
# Y(z)&=(9+4z^{-1})X(z)-1/3z^{-1}Y(z)\\\\
# y[n]&=9x[n]+4x[n-1]-\frac{1}{3}y[n-1]
# \end{align*}

# %% [markdown]
# # b)

# %% [markdown]
# \begin{align*}
# H(z)&=\frac{9+4z^{-1}}{1-1/3z^{-1}}\\
# \end{align*}

# %% [markdown]
# $$\frac{9+4z^{-1}}{1-1/3z^{-1}}=A+\frac{B}{1-1/3z^{-1}}$$

# %% [markdown]
# \begin{align*}
# A(1-1/3z^{-1})+B=9+4z^{-1}\\\\
# -1/3A&=4\\
# A&=-12\\\\
# A+B&=9\\
# B&=9-A\\
# B&=9+12\\
# B&=21
# \end{align*}

# %% [markdown]
# $$H(z)=\frac{21}{1-1/3z^{-1}}-18$$
# $$h[n]=21(\frac{1}{3})^n u[n]-12\delta [n]$$

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # (a)

# %% [markdown]
# \begin{align*}
# y[n]=x[n]+2r\cos(\theta)y[n-1]-r^2y[n-2]
# \end{align*}

# %% [markdown]
# # (b)

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# \begin{align}
# v [n]&=r\cos(\theta) v[n-1]+r\sin(\theta) y[n-2]+x[n]\\
# y[n]&=r\sin(\theta)v[n] +rcos(\theta)y[n-1]\\
# \end{align}

# %% [markdown]
# ved at løse for $v[n]$ i (2) får jeg
#
# $$v[n]=\frac{y[n]-r\cos(\theta)y[n-1]}{rsin(\theta)}$$

# %% [markdown]
# derefter sætter jeg $v[n]$ ind i (1) og løser for y[n]

# %% [markdown]
# \begin{align*}
# \frac{y[n]-r\cos(\theta)y[n-1]}{rsin(\theta)}&=r\cos(\theta) \frac{y[n-1]-r\cos(\theta)y[n-2]}{rsin(\theta)}+r\sin(\theta) y[n-2]+x[n]
# \end{align*}

# %% [markdown]
# \begin{align*}
# y[n]&=r\cos(\theta)y[n-1]-r^2\cos^2(\theta)y[n-2]+r^2\sin^2(\theta)y[n-2]+r\sin(\theta)x[n]+r\cos(\theta)y[n-1]\\
# &=2r\cos(\theta)y[n-1]-r^2\cos^2(\theta)y[n-2]+r^2\sin^2(\theta)y[n-2]+r\sin(\theta)x[n]\\
# \end{align*}

# %% [markdown]
# svarliste, eneste forskel er en faktor $rsin(\theta)$ ikke er på deres $x[n]$ måske pga af fejl

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Alternativ løsnings forsøg, bliver ret forkert

# %% [markdown]
# \begin{align*}
# Y(z)&=r\sin(\theta)V(z) +z^{-1}rcos(\theta)Y(z)\\
# Y(z)&=\frac{r\sin(\theta)}{1-z^{-1}}V(z)\\
# \frac{Y(z)}{V(z)}&=\frac{r\sin(\theta)}{1-z^{-1}}\\\\
# \end{align*}

# %% [markdown]
# \begin{align*}
# V(z)&=r\cos(\theta) z^{-1}V(z)+r\sin(\theta) z^{-2}\frac{r\sin(\theta)}{1-z^{-1}}V(z)+X(z)\\\\
# \frac{V(z)}{X(z)}&=\frac{1}{1-r\cos(\theta) z^{-1}-r\sin(\theta) z^{-2}\frac{r\sin(\theta)}{1-z^{-1}}}\\
# &=\frac{1}{1-r\cos(\theta) z^{-1}-z^{-2}\frac{r^2\sin^2(\theta)}{1-z^{-1}}}
# \end{align*}

# %% [markdown]
# \begin{align*}
# \frac{Y(z)}{X(z)}&=\frac{r\sin(\theta)}{1-z^{-1}} \frac{1}{1-r\cos(\theta) z^{-1}-z^{-2}\frac{r^2\sin^2(\theta)}{1-z^{-1}}}
# \end{align*}

# %% [markdown]
# \begin{align*}
# \frac{Y(z)}{X(z)}&=\frac{r\sin(\theta)}{1-z^{-1}-rcos(\theta)z^{-1}+rcos(\theta)z^{-2}-z^{-2}r^2sin^2(\theta)}\\
# \end{align*}

# %% [markdown]
# \begin{align*}
# Y(z)(1-z^{-1}-rcos(\theta)z^{-1}+rcos(\theta)z^{-2}-z^{-2}r^2sin^2(\theta))&=r\sin(\theta)X(z)
#
# \end{align*}

# %% [markdown]
# \begin{align*}
# y[n]=&r\sin(\theta)x[n]+y[n-1]+rcos(\theta)y[n-1]\\
# &-rcos(\theta)y[n-2]+r^2sin^2(\theta)y[n-2]
# \end{align*}

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# close enough

# %% [markdown]
# d.v.s de 2 flow diagrammer representerer ikke det samme system.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# kun d)

# %% [markdown]
# # d)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# kun c)

# %% [markdown]
# # c)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
